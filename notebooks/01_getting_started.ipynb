# %% [raw]
# # 🏈 Football Betting Prediction Bot - Getting Started
#
# Welcome to your football betting prediction system! This notebook will help you explore the project and get familiar with the components.
#
# ## 📋 What We'll Cover:
# 1. **Project Overview** - Understanding the structure
# 2. **Database Exploration** - Check our data models
# 3. **Configuration** - Review settings
# 4. **Data Sources** - Explore collection options
# 5. **Next Steps** - Where to go from here

# %% [raw]
# ## 🔧 Setup and Imports

# %%
# Add src to path so we can import our modules
import sys
sys.path.append('../src')

# Essential imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta
import warnings
warnings.filterwarnings('ignore')

# Set up plotting
plt.style.use('default')
plt.rcParams['figure.figsize'] = (12, 6)

print("✅ All imports successful!")
print(f"📅 Current date: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %% [raw]
# ## ⚙️ Check Configuration

# %%
# Test our configuration system
from config.settings import settings

print("🔧 Configuration Status:")
print(f"   Database URL: {settings.database_url}")
print(f"   Debug Mode: {settings.debug}")
print(f"   Log Level: {settings.log_level}")
print(f"   Max Daily Bets: {settings.max_daily_bets}")
print(f"   Initial Bankroll: ${settings.initial_bankroll}")
print(f"   Leagues: {settings.leagues_list}")

print("\n✅ Configuration loaded successfully!")

# %% [raw]
# ## 🚀 Quick Commands Reference
#
# After exploring this notebook, copy these commands to your terminal:
#
# ```bash
# # Test the database
# python src/data/storage/init_db.py
#
# # Test data collectors (needs API keys)
# python src/data/collectors/football_api.py
#
# # Install Kaggle CLI
# pip install kaggle
#
# # Check logs
# dir logs\
# ```
#
# ## 🎯 Next Steps
# 1. **Test the Database** - Run the database initialization
# 2. **Get API Keys** - Sign up for free accounts
# 3. **Download Sample Data** - Start with Kaggle datasets
# 4. **Build Models** - Create your first predictions!
